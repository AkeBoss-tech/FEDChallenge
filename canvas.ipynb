# %% [markdown]
# # Reading Data from Canvas Sheet
# I was looking at the sheet he gave us and I realized that the data is in a good format for people to read but not a good format for a computer to read.
# We should look through the sheet ourselves and see which series we want to use. Then we can use the BLS API to get the data and graph it.

# %%
# read professor stone's excel file in pandas
import pandas as pd
import numpy as np

# read xlsx file
df = pd.read_excel('data\canvas_data.xls')
df.head()
# Out:
#   Unnamed: 0     Unnamed: 1     Unnamed: 2       Unnamed: 3  \
# 0       Code  CES0000000001  CES0500000001    CES0600000001
# 1        NaN            NaN            NaN              NaN
# 2        NaN            NaN            NaN              NaN
# 3        NaN  Total nonfarm  Total private  Goods-producing
# 4        NaN  Total nonfarm  Total private  Goods-producing
#
#            Unnamed: 4     Unnamed: 5                 Unnamed: 6  \
# 0       CES1000000001  CES2000000001              CES2023600001
# 1                 NaN            NaN                        NaN
# 2                 NaN            NaN                        NaN
# 3  Mining and logging   Construction  Construction of buildings
# 4  Mining and logging   Construction  Construction of buildings
#
#              Unnamed: 7               Unnamed: 8  \
# 0         CES2023610001            CES2023620001
# 1                   NaN                      NaN
# 2                   NaN                      NaN
# ...

# %% [markdown]
# I used the rest of this sheet to play around with BLS API and see how it works. To make the function I showed to graph data.

# %%
# %pip install bls
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\akash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\akash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\akash\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\akash\appdata\roaming\python\python310\site-packages)

# %%
from bls import get_series
import os

os.environ['BLS_API_KEY'] = '07edf8b5d4784b52a2b1b0ef1b18ba0f'

unemployment_data = get_series('LNS14000000') 
len(unemployment_data)
# Out:
# 116

# %%
# plot the unemployment_data with seaborn
import seaborn as sns
import matplotlib.pyplot as plt

# graph pandas series with seaborn
# Plotting the Series using Seaborn
x = unemployment_data.index.to_timestamp()
y = unemployment_data.values
sns.lineplot(x=x, y=y)

# Show the plot
plt.show()
